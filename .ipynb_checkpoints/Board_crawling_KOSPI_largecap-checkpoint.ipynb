# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import requests
import pandas as pd
import re
import time
import os

headers = {'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3)'}

# %%
def Crawler_many(x_code, x_name, x_page):
    # start = time.time()
    df = pd.DataFrame(columns = [
    'name',
    'date',
    'title',
    'content',
    'click',
    'good',
    'bad'
    ])
    
    # 마지막 페이지
    url = "https://finance.naver.com/item/board.nhn?code={}&page={}".format(x_code, 1)
    html = requests.get(url, headers = headers).text
    soup = bs(html, 'html.parser')
    last_page = soup.select('#content > div.section.inner_sub > table:nth-child(3) > tbody > tr > td:nth-child(2) > table > tbody > tr > td.pgRR ')[0]
    last_page = last_page.find('a')
    last_page = last_page.attrs['href'][33:]
    last_page = int(last_page)
    # print(last_page)

    if page == 'all':
        for p in range(1, last_page+1):
            url = "https://finance.naver.com/item/board.nhn?code={}&page={}".format(x_code, p)
            html = requests.get(url, headers = headers).text
            soup = bs(html, 'html.parser')
            base = soup.select('#content > div.section.inner_sub > table.type2 > tbody')[0]
            
            for i in range(3, 26):
                # 5칸마다 있는 줄에 해당할 경우 contunue
                try:
                    if i == 8 or i == 14 or i == 20:
                        continue

                    date = base.select('tr:nth-child({}) > td:nth-child(1) > span'.format(i))[0].text
                except:
                    break

                title = base.select('tr:nth-child({}) > td.title > a'.format(i))[0].text
                click = base.select('tr:nth-child({}) > td:nth-child(4) > span'.format(i))[0].text
                good = base.select('tr:nth-child({}) > td:nth-child(5) > strong'.format(i))[0].text
                bad = base.select('tr:nth-child({}) > td:nth-child(6) > strong'.format(i))[0].text

                # href 얻기
                href = base.select('tr:nth-child({}) > td.title'.format(i))[0]
                href = href.find('a')
                href = href.attrs['href']

                # 본문 내용 얻기
                content_url = ('https://finance.naver.com'+ href)
                content_html = requests.get(content_url, headers = headers).text
                content_soup = bs(content_html, 'html.parser')
                content = content_soup.find("div", "view_se").text

                # df에 저장
                result = {
                    'name':x_name,
                    'date':date,
                    'title':title,
                    'content':content,
                    'click':click,
                    'good':good,
                    'bad':bad
                    }
                df = df.append(result, ignore_index = True)
                #end = time.time()
                #print("경과 시간: {}".format(end - start))
    else:
        if last_page < x_page:
            x_page = last_page   
            
        for p in range(1, x_page+1):
            url = "https://finance.naver.com/item/board.nhn?code={}&page={}".format(x_code, p)
            html = requests.get(url, headers = headers).text
            soup = bs(html, 'html.parser')
            base = soup.select('#content > div.section.inner_sub > table.type2 > tbody')[0]

            for i in range(3, 26):
                # 5칸마다 있는 줄에 해당할 경우 contunue
                try:
                    if i == 8 or i == 14 or i == 20:
                        continue

                    date = base.select('tr:nth-child({}) > td:nth-child(1) > span'.format(i))[0].text
                except:
                    break

                title = base.select('tr:nth-child({}) > td.title > a'.format(i))[0].text
                click = base.select('tr:nth-child({}) > td:nth-child(4) > span'.format(i))[0].text
                good = base.select('tr:nth-child({}) > td:nth-child(5) > strong'.format(i))[0].text
                bad = base.select('tr:nth-child({}) > td:nth-child(6) > strong'.format(i))[0].text

                # href 얻기
                href = base.select('tr:nth-child({}) > td.title'.format(i))[0]
                href = href.find('a')
                href = href.attrs['href']

                # 본문 내용 얻기
                content_url = ('https://finance.naver.com'+ href)
                content_html = requests.get(content_url, headers = headers).text
                content_soup = bs(content_html, 'html.parser')
                content = content_soup.find("div", "view_se").text

                # df에 저장
                result = {
                    'name':x_name,
                    'date':date,
                    'title':title,
                    'content':content,
                    'click':click,
                    'good':good,
                    'bad':bad
                    }
                df = df.append(result, ignore_index = True)
            #end = time.time()
            #print("경과 시간: {}".format(end - start))
    return df

# %%
# 코드 불러오기
stock_list = pd.read_excel('Stock_list/코스피 대형주_20210219.xlsx')
stock_list = stock_list[['종목코드', '종목명']]
stock_list.head(10)
# Out:
#      종목코드       종목명
# 0    5930      삼성전자
# 1     660    SK하이닉스
# 2   51910      LG화학
# 3   35420     NAVER
# 4    6400     삼성SDI
# 5  207940  삼성바이오로직스
# 6    5380       현대차
# 7   35720       카카오
# 8   68270      셀트리온
# 9     270       기아차

# %%
# 종목코드 앞에 0넣기

for i in range(len(stock_list)):
    if len(str(stock_list['종목코드'][i])) != 6:
        #stock_list['종목코드'][i] = format(stock_list['종목코드'][i], '06')
        stock_list.loc[i, '종목코드'] = format(stock_list['종목코드'][i], '06')

print(stock_list)
# Out:
#       종목코드      종목명
# 0   005930     삼성전자
# 1   000660   SK하이닉스
# 2   051910     LG화학
# 3   035420    NAVER
# 4   006400    삼성SDI
# ..     ...      ...
# 95  007310      오뚜기
# 96  001450     현대해상
# 97  138930  BNK금융지주
# 98  002380      KCC
# 99  000210       DL
#
# [100 rows x 2 columns]

# %%
# 코드 실행
for i in range(len(stock_list)):
    code = stock_list['종목코드'][i]
    name = stock_list['종목명'][i]
    page = 10
    
    df = Crawler_many(code, name, page)
    df.to_excel('KOSPI_largecap/{}_result.xlsx'.format(code))
    
    print('*****{} 완료*****'.format(name))
# Out:
# *****삼성전자 완료*****
# *****SK하이닉스 완료*****
# *****LG화학 완료*****
# %20%5b출처%5d%20NAVER%20-%20후불결제%20허용은%20이커머스%20시장에%20전환점%20될%20것|작성자%20pokara61' with link or location/anchor > 2079 characters since it exceeds Excel's limit for URLS
#   warn("Ignoring URL '%s' with link or location/anchor > %d "
# *****NAVER 완료*****
# *****삼성SDI 완료*****
# *****삼성바이오로직스 완료*****
# *****현대차 완료*****
# *****카카오 완료*****
# *****셀트리온 완료*****
# *****기아차 완료*****
# *****현대모비스 완료*****
# *****LG전자 완료*****
# *****SK이노베이션 완료*****
# *****LG생활건강 완료*****
# *****삼성물산 완료*****
# *****POSCO 완료*****
# *****엔씨소프트 완료*****
# *****SK텔레콤 완료*****
# *****SK 완료*****
